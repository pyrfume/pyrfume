# %%
import re
import requests
from urllib.request import quote
import pandas as pd
import bs4

# %%
df = pd.read_excel('data/vcd_database.xlsx')

# %%
cas_list = set(list(df.iloc[:,6].replace(0,None).dropna())[1:])
print(len(cas_list))
# Out:
# 119

# %%
cas_cid_smiles = pd.DataFrame(columns=['CID', 'SMILES'])
for cas in list(cas_list):
    url = "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/%s/property/isomericSMILES/JSON" % cas
    r = requests.get(url)
    if r.status_code == 200:
        xs = r.json()['PropertyTable']['Properties']
        found_chiral_smiles = False
        for x in xs:
            if any([char in x['IsomericSMILES'] for char in ['@','@@','/','\\']]): # Is chiral
                cas_cid_smiles.loc[cas] = [x['CID'], x['IsomericSMILES']]
                found_chiral_smiles = True
                break
        if not found_chiral_smiles:
            print("No chiral SMILES found for CAS %s" % cas)
    else:
        print("No result for CAS %s" % cas)
cas_cid_smiles['Type'] = 'Original'
cas_cid_smiles['Enantiomer'] = ''
print(cas_cid_smiles.shape[0])
# Out:
# No result for CAS 28283-97-8
# No chiral SMILES found for CAS 564-94-3
# No chiral SMILES found for CAS 536-59-4
# No chiral SMILES found for CAS 99-83-2
# 115

# %%
original_smiles_list = list(cas_cid_smiles['SMILES'])
original_cas_list = list(cas_cid_smiles.index)
for i,smiles in enumerate(original_smiles_list):
    smiles_m = smiles.replace('@@','a').replace('@','b').replace('/','c').replace('\\','d')\
                     .replace('a','@').replace('b','@@').replace('c','\\').replace('d','/')             
    url = "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/smiles/%s/synonyms/JSON" % quote(smiles_m)  
    r = requests.get(url)
    if r.status_code == 200:
        x = r.json()['InformationList']['Information'][0]
        CID = x['CID']
        found_cas = False
        for synonym in x['Synonym']:
            if re.match('[0-9]+-[0-9]+-[0-9]+', synonym) and ' ' not in synonym:
                found_cas = True
                cas = synonym
                original_cas = cas_cid_smiles.index[i]
                if cas == original_cas:
                    print('Rejected identical CAS %s' % cas)
                    continue
                if cas in original_cas_list:
                    print('Already have data on CAS %s' % cas)
                    continue
                cas_cid_smiles.loc[cas] = [x['CID'], smiles_m, 'Mirrored', original_cas]
                cas_cid_smiles.loc[original_cas, 'Enantiomer'] = cas
                break
        if not found_cas:
            print("No CAS found for mirror SMILES %s" % smiles_m)
    else:
        print("No result for mirror SMILES string %s" % smiles_m)
print(cas_cid_smiles.shape[0])
# Out:
# Already have data on CAS 302911-94-0
# Already have data on CAS 17392-83-5
# Already have data on CAS 1845-25-6
# Already have data on CAS 33758-15-5
# No result for mirror SMILES string CCCCC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# Already have data on CAS 72657-23-9
# Already have data on CAS 16404-54-9
# Already have data on CAS 2216-51-5
# No result for mirror SMILES string CC(C)[C@H]1CC[C@@]2([C@@H]3[C@H]1[C@@H]4[C@]2([C@@H]4C3)C)C
# Already have data on CAS 103128-76-3
# Already have data on CAS 2767-84-2
# Already have data on CAS 464-48-2
# Already have data on CAS 22144-60-1
# No result for mirror SMILES string CCCCCCCC\C=C/CCCCCCCCOC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# Already have data on CAS 2623-23-6
# Already have data on CAS 83541-68-8
# Already have data on CAS 80657-57-4
# Already have data on CAS 89-82-7
# No result for mirror SMILES string CCCCCC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# Already have data on CAS 3391-90-0
# No result for mirror SMILES string CCCC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# Already have data on CAS 70419-06-6
# No CAS found for mirror SMILES C[C@H]1[C@@H]2C[C@@]2(CC1=O)C(C)C
# Already have data on CAS 31087-44-2
# Already have data on CAS 20698-91-3
# No result for mirror SMILES string C[C@@H](CCCC(C)C)[C@@H]1CC[C@H]2[C@]1(CC[C@@H]3[C@@H]2CC=C4[C@]3(CC[C@H](C4)OC(=O)OC)C)C
# Already have data on CAS 5989-54-8
# Already have data on CAS 27871-49-4
# Already have data on CAS 26184-62-3
# No result for mirror SMILES string CCCCCCCC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# Already have data on CAS 146502-80-9
# No result for mirror SMILES string CCCCCCOC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# Already have data on CAS 10606-72-1
# Already have data on CAS 4221-99-2
# No result for mirror SMILES string CCCCCCCCCCCCCCCC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# Already have data on CAS 7785-26-4
# Already have data on CAS 26127-08-2
# No result for mirror SMILES string C[C@@H](CCCC(C)C)[C@@H]1CC[C@H]2[C@]1(CC[C@@H]3[C@@H]2CC[C@H]4[C@]3(CC[C@H](C4)O)C)C
# Already have data on CAS 1117-61-9
# Already have data on CAS 2244-16-8
# Already have data on CAS 104870-56-6
# Rejected identical CAS 74851-17-5
# No result for mirror SMILES string CCOC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# Already have data on CAS 10334-26-6
# Already have data on CAS 6033-23-4
# No result for mirror SMILES string CCCCCCCCCOC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# Already have data on CAS 83540-97-0
# No CAS found for mirror SMILES CC1([C@@H]2CC=C([C@H]1C2)CCO)C
# Already have data on CAS 22135-49-5
# Already have data on CAS 6033-24-5
# Already have data on CAS 5157-89-1
# Already have data on CAS 6485-40-1
# No CAS found for mirror SMILES CC1([C@@H]2C[C@H]1C3(C(C2)O3)C)C
# Already have data on CAS 70419-07-7
# Already have data on CAS 116910-11-3
# No result for mirror SMILES string CCCCCCC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# No CAS found for mirror SMILES CCCCCCCCCCCCCC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# No result for mirror SMILES string C[C@@H](CCCC(C)C)[C@@H]1CC[C@H]2[C@]1(CC[C@@H]3[C@@H]2CC=C4[C@]3(CC[C@H](C4)OC(=O)C)C)C
# Already have data on CAS 2552-91-2
# Already have data on CAS 26549-24-6
# Already have data on CAS 6169-06-8
# Already have data on CAS 5978-70-1
# Already have data on CAS 5949-05-3
# No CAS found for mirror SMILES C[C@H]1CC[C@H]([C@@H](C1)OCCl)C(C)C
# No CAS found for mirror SMILES C[C@@H](CCCC(C)C)[C@@H]1CC[C@H]2[C@]1(CC[C@@H]3[C@@H]2CC=C4[C@]3(CC[C@H](C4)Br)C)C
# No result for mirror SMILES string CCCCCCCCCC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# Already have data on CAS 14898-80-7
# Already have data on CAS 52019-78-0
# Already have data on CAS 2385-77-5
# No result for mirror SMILES string CCC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# Already have data on CAS 5989-27-5
# No CAS found for mirror SMILES C[C@@H](CCCC(C)C)[C@@H]1CC[C@H]2[C@]1(CC[C@@H]3[C@@H]2CC=C4[C@]3(CC[C@H](C4)O)C)C
# Rejected identical CAS 475-20-7
# Already have data on CAS 464-49-3
# Already have data on CAS 13704-09-1
# Already have data on CAS 14898-79-4
# No result for mirror SMILES string CCCCCCCOC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# Already have data on CAS 89-79-2
# Already have data on CAS 7540-51-4
# Already have data on CAS 15356-60-2
# Already have data on CAS 21210-43-5
# Already have data on CAS 7785-70-8
# Already have data on CAS 24047-72-1
# Already have data on CAS 33758-16-6
# No result for mirror SMILES string C[C@@H](CCCC(C)C)[C@@H]1CC[C@H]2[C@]1(CC[C@@H]3[C@@H]2CC=C4[C@]3(CC[C@H](C4)Cl)C)C
# No result for mirror SMILES string CCCCCCCCC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# No result for mirror SMILES string CCCCOC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# No result for mirror SMILES string CCCCCOC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# No result for mirror SMILES string CCCCCCCCCCCC(=O)O[C@@H]1CC[C@]2([C@@H]3CC[C@@]4([C@@H]([C@H]3CC=C2C1)CC[C@H]4[C@@H](C)CCCC(C)C)C)C
# 156

# %%
cas_cid_smiles['Type'].value_counts()
# Out:
# Original    115
# Mirrored     41
# Name: Type, dtype: int64

# %%
# This should print nothing if all the SMILES strings have stereometic information
for i,s in enumerate(cas_cid_smiles['SMILES']):
    if not any([x in s for x in ['@','@@','/','\\']]):
        print('This SMILES string has no stereomeric information: CAS=%s; CID=%d; SMILES=%s' % (cas_cid_smiles['Type'][i],cas_cid_smiles.index[i],cas_cid_smiles['CID'][i],s))

# %%
pairs = cas_cid_smiles[cas_cid_smiles['Enantiomer'] != '']
print("There are %d pairs of enantiomers for which we have VCD spectra for at least one member of the pair." % (len(pairs)/2))
# Out:
# There are 42 pairs of enantiomers for which we have VCD spectra for at least one member of the pair.

# %%
pairs
# Out:
#                   CID                                        SMILES      Type  \
# 18172-67-3     440967                  CC1([C@H]2CCC(=C)[C@@H]1C2)C  Original
# 116910-11-3   7157231              CC(C)[C@H]1CO[C@]2(N1C(=O)C=C2)C  Original
# 15356-60-2     165675              C[C@H]1CC[C@@H]([C@H](C1)O)C(C)C  Original
# 53369-17-8     104476             CC1([C@H]2CC[C@@H]([C@@H]1C2)CO)C  Original
# 2217-02-9     6997371           C[C@@]12CC[C@@H](C1)C([C@@H]2O)(C)C  Original
# 5157-89-1       62335        C[C@H]1CC[C@@H]([C@H](C1)OC(=O)C)C(C)C  Original
# 3391-90-0      638012                     C[C@H]1CCC(=C(C)C)C(=O)C1  Original
# 27779-29-9      90350        C[C@H]1[C@@H]2C[C@@H](C2(C)C)C[C@@H]1O  Original
# 1767-46-0    13463446                                CC[C@H](C)CCCO  Original
# 5989-27-5      440917                       CC1=CC[C@@H](CC1)C(=C)C  Original
# 19894-97-4      88301                 CC1([C@H]2CC=C([C@@H]1C2)CO)C  Original
# 17392-83-5     637514                              C[C@H](C(=O)OC)O  Original
# 2552-91-2       75699        C[C@@H]1CC[C@H]([C@H](C1)OC(=O)C)C(C)C  Original
# 14073-97-3      26447                 C[C@@H]1CC[C@H](C(=O)C1)C(C)C  Original
# 7785-70-8       82227                    CC1=CC[C@@H]2C[C@H]1C2(C)C  Original
# 118-65-0      5281522       C/C/1=C/CCC(=C)[C@H]2CC([C@@H]2CC1)(C)C  Original
# 6485-40-1      439570                      CC1=CC[C@H](CC1=O)C(=C)C  Original
# 25465-65-0   10524983          C[C@@H]1[C@H]2C[C@H](C2(C)C)C[C@H]1O  Original
# 110453-78-6  13548104                              CC[C@H](C)CCCCCO  Original
# 56777-24-3   11052238                  C[C@@H](C(=O)OCC1=CC=CC=C1)O  Original
# 16052-42-9     244509            C[C@@H]1CC[C@H]([C@@H](C1)Cl)C(C)C  Original
# 113473-32-8    688339  CC1([C@@H]2C[C@H]1C(=O)C=C2COC(=O)C(C)(C)C)C  Original
# 42072-39-9     641003                                 CC[C@H](C)CCO  Original
# 19210-21-0     641045                                 C[C@@H](CO)Cl  Original
# 146502-80-9   6432249       C[C@H]1CC[C@@H]([C@@H](C1)OC(=O)C)C(C)C  Original
# 5978-70-1       80080                              CCCCCC[C@@H](C)O  Original
# 6169-06-8     2723888                               CCCCCC[C@H](C)O  Original
# 1565-80-6     2723602                                  CC[C@H](C)CO  Original
# 464-45-9      1201518                C[C@]12CC[C@H](C1(C)C)C[C@H]2O  Original
# 5949-05-3      443157                        C[C@@H](CCC=C(C)C)CC=O  Original
# ...               ...                                           ...       ...
# 103315-49-7     94386                             C[C@@H](C(=O)OC)O  Mirrored
# 2230-87-7       75699        C[C@@H]1CC[C@H]([C@H](C1)OC(=O)C)C(C)C  Mirrored
# 3391-87-5      443159                 C[C@H]1CC[C@@H](C(=O)C1)C(C)C  Mirrored
# 2437-95-8      440968                    CC1=CC[C@H]2C[C@@H]1C2(C)C  Mirrored
# 10579-93-8    5452236       C\C\1=C\CCC(=C)[C@@H]2CC([C@H]2CC1)(C)C  Mirrored
# 53763-73-8      16724                     CC1=CC[C@@H](CC1=O)C(=C)C  Mirrored
# 24041-60-9      90350        C[C@H]1[C@@H]2C[C@@H](C2(C)C)C[C@@H]1O  Mirrored
# 97730-24-0   13548103                             CC[C@@H](C)CCCCCO  Mirrored
# 74094-05-6    5324736                   C[C@H](C(=O)OCC1=CC=CC=C1)O  Mirrored
# 104012-59-1  10197918             C[C@H]1CC[C@@H]([C@H](C1)Cl)C(C)C  Mirrored
# 76163-96-7     688338  CC1([C@H]2C[C@@H]1C(=O)C=C2COC(=O)C(C)(C)C)C  Mirrored
# 70224-28-1    6999792                                CC[C@@H](C)CCO  Mirrored
# 37493-14-4     181530                                  C[C@H](CO)Cl  Mirrored
# 113301-48-7   2723888                               CCCCCC[C@H](C)O  Mirrored
# 4128-32-9       80080                              CCCCCC[C@@H](C)O  Mirrored
# 616-16-0       637572                                 CC[C@@H](C)CO  Mirrored
# 464-43-7      6552009             C[C@@]12CC[C@@H](C1(C)C)C[C@@H]2O  Mirrored
# 951036-03-6     75427                         C[C@H](CCC=C(C)C)CC=O  Mirrored
# 20747-49-3    6566020             C[C@H]1CC[C@@H]([C@@H](C1)O)C(C)C  Mirrored
# 4695-62-9     1201521                 C[C@]12CC[C@H](C1)C(C2=O)(C)C  Mirrored
# 65996-98-7     440917                       CC1=CC[C@@H](CC1)C(=C)C  Mirrored
# 48113-22-0     159055                 C[C@@]12CC[C@@H](C1(C)C)CC2=O  Mirrored
# 20296-50-8     442461                  CC1=CC[C@H]2[C@@H](C1)C2(C)C  Mirrored
# 50373-36-9     170833            C[C@@H]1CC[C@H]([C@@H](C1)O)C(=C)C  Mirrored
# 18457-55-1     369312                       CC(=C)[C@H]1CCC(=CC1)CO  Mirrored
# 77982-63-9     157139                  CC1([C@@H]2CCC(=O)[C@H]1C2)C  Mirrored
# 22422-34-0    6553875      C[C@]1([C@@H]2C[C@@H](C2(C)C)C[C@@H]1O)O  Mirrored
# 22148-86-3    6994425                       C[C@@H](CCC1=CC=CC=C1)O  Mirrored
# 74057-29-7   13218085                              CC[C@@H](C)CCCCO  Mirrored
# 34857-28-8    5325937                     CC(C)[C@@H](C1=CC=CC=C1)O  Mirrored
#
#               Enantiomer
# 18172-67-3    19902-08-0
# 116910-11-3  222629-69-8
# 15356-60-2       89-78-1
# 53369-17-8   132203-71-5
# 2217-02-9       512-13-0
# 5157-89-1        89-48-5
# 3391-90-0     90449-51-7
# 27779-29-9     1196-00-5
# 1767-46-0     53353-04-1
# 5989-27-5      7721-11-1
# 19894-97-4     6712-78-3
# 17392-83-5   103315-49-7
# 2552-91-2      2230-87-7
# 14073-97-3     3391-87-5
# 7785-70-8      2437-95-8
# 118-65-0      10579-93-8
# 6485-40-1     53763-73-8
# 25465-65-0    24041-60-9
# 110453-78-6   97730-24-0
# 56777-24-3    74094-05-6
# 16052-42-9   104012-59-1
# 113473-32-8   76163-96-7
# 42072-39-9    70224-28-1
# 19210-21-0    37493-14-4
# 146502-80-9    2230-87-7
# 5978-70-1    113301-48-7
# 6169-06-8      4128-32-9
# 1565-80-6       616-16-0
# 464-45-9        464-43-7
# 5949-05-3    951036-03-6
# ...                  ...
# 103315-49-7   17392-83-5
# 2230-87-7    146502-80-9
# 3391-87-5     14073-97-3
# 2437-95-8      7785-70-8
# 10579-93-8      118-65-0
# 53763-73-8     6485-40-1
# 24041-60-9    25465-65-0
# 97730-24-0   110453-78-6
# 74094-05-6    56777-24-3
# 104012-59-1   16052-42-9
# 76163-96-7   113473-32-8
# 70224-28-1    42072-39-9
# 37493-14-4    19210-21-0
# 113301-48-7    5978-70-1
# 4128-32-9      6169-06-8
# 616-16-0       1565-80-6
# 464-43-7        464-45-9
# 951036-03-6    5949-05-3
# 20747-49-3     2216-52-6
# 4695-62-9      7787-20-4
# 65996-98-7     5989-54-8
# 48113-22-0      464-48-2
# 20296-50-8      498-15-7
# 50373-36-9   104870-56-6
# 18457-55-1    57717-97-2
# 77982-63-9    38651-65-9
# 22422-34-0    18680-27-8
# 22148-86-3    39516-03-5
# 74057-29-7    57803-73-3
# 34857-28-8    14898-86-3
#
# [84 rows x 4 columns]

# %%
def cas2soup(cas):
    import requests
    base_url = "http://www.thegoodscentscompany.com"
    url = "%s/search3.php?qName=%s&submit.x=0&submit.y=0" % (base_url,cas)
    response = requests.get(url)
    index = response.text.find('data/')
    soup = None
    if index > 0:
        path = response.text[index:(index+25)].split("'")[0]
        url = "%s/%s" % (base_url,path)
        response = requests.get(url)
        soup = bs4.BeautifulSoup(response.text)
    return soup

# %%
def soup2odor(soup):
    chem_tables = soup.find_all("table",{"class":"cheminfo"})
    odor = None
    for t in chem_tables:
        if 'Odor' in t.text:
            odor = [x.text for x in t.find_all('td')]
            break
    return odor

# %%
cas_odors = {}
for cas in cas_cid_smiles.index:
    print(cas)
    soup = cas2soup(cas)
    if soup:
        odor = soup2odor(soup)
        if odor:
            print("Found odor info for %s" % cas)
            cas_odors[cas] = odor
# Out:
# 18172-67-3
# Found odor info for 18172-67-3
# 116910-11-3
# 27871-49-4
# Found odor info for 27871-49-4
# 24047-72-1
# 33758-16-6
# 7726-03-6
# Found odor info for 7726-03-6
# 80657-57-4
# 14898-80-7
# Found odor info for 14898-80-7
# 15356-60-2
# Found odor info for 15356-60-2
# 22469-52-9
# Found odor info for 22469-52-9
# 26127-08-2
# 53369-17-8
# Found odor info for 53369-17-8
# 10334-26-6
# 2217-02-9
# Found odor info for 2217-02-9
# 464-49-3
# Found odor info for 464-49-3
# 22135-49-5
# 17110-51-9
# Found odor info for 17110-51-9
# 5157-89-1
# Found odor info for 5157-89-1
# 83540-97-0
# 72657-23-9
# 3391-90-0
# Found odor info for 3391-90-0
# 1062-96-0
# 89-82-7
# Found odor info for 89-82-7
# 521-13-1
# Found odor info for 521-13-1
# 27779-29-9
# Found odor info for 27779-29-9
# 1767-46-0
# Found odor info for 1767-46-0
# 70419-07-7
# 546-80-5
# Found odor info for 546-80-5
# 26184-62-3
# Found odor info for 26184-62-3
# 21210-43-5
# 15507-52-5
# 5989-27-5
# Found odor info for 5989-27-5
# 19894-97-4
# Found odor info for 19894-97-4
# 17392-83-5
# Found odor info for 17392-83-5
# 31087-44-2
# Found odor info for 31087-44-2
# 1182-42-9
# Found odor info for 1182-42-9
# 2552-91-2
# Found odor info for 2552-91-2
# 15455-80-8
# 13704-09-1
# 14073-97-3
# Found odor info for 14073-97-3
# 14898-79-4
# Found odor info for 14898-79-4
# 601-34-3
# Found odor info for 601-34-3
# 7785-70-8
# Found odor info for 7785-70-8
# 118-65-0
# Found odor info for 118-65-0
# 103128-76-3
# 80-97-7
# Found odor info for 80-97-7
# 7540-51-4
# Found odor info for 7540-51-4
# 6485-40-1
# Found odor info for 6485-40-1
# 89-79-2
# Found odor info for 89-79-2
# 74851-17-5
# 23836-43-3
# 2767-84-2
# 6033-24-5
# Found odor info for 6033-24-5
# 15455-83-1
# 83541-68-8
# 35836-73-8
# Found odor info for 35836-73-8
# 25465-65-0
# Found odor info for 25465-65-0
# 110453-78-6
# 22144-60-1
# 6033-23-4
# Found odor info for 6033-23-4
# 2623-23-6
# Found odor info for 2623-23-6
# 2244-16-8
# Found odor info for 2244-16-8
# 72936-74-4
# 70419-06-6
# 56777-24-3
# 16052-42-9
# Found odor info for 16052-42-9
# 302911-94-0
# 113473-32-8
# 1182-07-6
# Found odor info for 1182-07-6
# 42072-39-9
# Found odor info for 42072-39-9
# 1989-52-2
# Found odor info for 1989-52-2
# 604-35-3
# Found odor info for 604-35-3
# 19210-21-0
# 146502-80-9
# 52019-78-0
# Found odor info for 52019-78-0
# 5978-70-1
# Found odor info for 5978-70-1
# 6169-06-8
# Found odor info for 6169-06-8
# 1565-80-6
# Found odor info for 1565-80-6
# 2385-77-5
# Found odor info for 2385-77-5
# 144177-48-0
# 516-91-6
# 464-45-9
# Found odor info for 464-45-9
# 1183-04-6
# Found odor info for 1183-04-6
# 16404-54-9
# Found odor info for 16404-54-9
# 26549-24-6
# Found odor info for 26549-24-6
# 5949-05-3
# Found odor info for 5949-05-3
# 633-31-8
# Found odor info for 633-31-8
# 2216-52-6
# Found odor info for 2216-52-6
# 7787-20-4
# Found odor info for 7787-20-4
# 5989-54-8
# Found odor info for 5989-54-8
# 57-88-5
# Found odor info for 57-88-5
# 475-20-7
# Found odor info for 475-20-7
# 464-48-2
# Found odor info for 464-48-2
# 10606-72-1
# 498-15-7
# Found odor info for 498-15-7
# 4221-99-2
# Found odor info for 4221-99-2
# 15455-81-9
# 104870-56-6
# 1117-61-9
# Found odor info for 1117-61-9
# 57717-97-2
# Found odor info for 57717-97-2
# 2216-51-5
# Found odor info for 2216-51-5
# 20698-91-3
# 7785-26-4
# Found odor info for 7785-26-4
# 1845-25-6
# 33758-15-5
# 38651-65-9
# Found odor info for 38651-65-9
# 910-31-6
# Found odor info for 910-31-6
# 18680-27-8
# Found odor info for 18680-27-8
# 39516-03-5
# Found odor info for 39516-03-5
# 1182-66-7
# Found odor info for 1182-66-7
# 57803-73-3
# Found odor info for 57803-73-3
# 41371-14-6
# 15455-79-5
# 1908-11-8
# Found odor info for 1908-11-8
# 14898-86-3
# 19902-08-0
# Found odor info for 19902-08-0
# 222629-69-8
# 89-78-1
# Found odor info for 89-78-1
# 132203-71-5
# 512-13-0
# Found odor info for 512-13-0
# 89-48-5
# Found odor info for 89-48-5
# 90449-51-7
# 1196-00-5
# Found odor info for 1196-00-5
# 53353-04-1
# 7721-11-1
# 6712-78-3
# Found odor info for 6712-78-3
# 103315-49-7
# 2230-87-7
# Found odor info for 2230-87-7
# 3391-87-5
# Found odor info for 3391-87-5
# 2437-95-8
# 10579-93-8
# 53763-73-8
# 24041-60-9
# Found odor info for 24041-60-9
# 97730-24-0
# 74094-05-6
# 104012-59-1
# 76163-96-7
# 70224-28-1
# Found odor info for 70224-28-1
# 37493-14-4
# 113301-48-7
# 4128-32-9
# 616-16-0
# Found odor info for 616-16-0
# 464-43-7
# Found odor info for 464-43-7
# 951036-03-6
# 20747-49-3
# 4695-62-9
# Found odor info for 4695-62-9
# 65996-98-7
# Found odor info for 65996-98-7
# 48113-22-0
# 20296-50-8
# Found odor info for 20296-50-8
# 50373-36-9
# 18457-55-1
# Found odor info for 18457-55-1
# 77982-63-9
# 22422-34-0
# Found odor info for 22422-34-0
# 22148-86-3
# Found odor info for 22148-86-3
# 74057-29-7
# 34857-28-8

# %%
print("We have GoodScents odors information for %d molecules in the enantiomer set" % len(cas_odors))
# Out:
# We have GoodScents odors information for 92 molecules in the enantiomer set

# %%
x = cas_cid_smiles.copy()
x['Odor'] = 0
for cas in cas_odors:
    x.loc[cas,'Odor'] = 1
x2 = x[(x['Odor']==1) & (x['Enantiomer'] != '')]
x3 = x2[x2['Enantiomer'].isin(list(x2.index))]
print("We have odor info and spectra for %d enantiomers (%d pairs)" % (len(x3), len(x3)/2))
# Out:
# We have odor info and spectra for 36 enantiomers (18 pairs)

# %%
x3.shape
# Out:
# (36, 6)

# %%
x3['Strength'] = ''
for cas, odor in cas_odors.items():
    for o in odor:
        if 'Odor Strength' in o:
            strength = o.split(':')[1].split(',')[0].strip()
            if cas in x3.index:
                x3.loc[cas, 'Strength'] = strength
# Out:
# /Users/rgerkin/Dropbox/miniconda3/lib/python3.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
x3
# Out:
#                  CID                                    SMILES      Type  \
# 18172-67-3    440967              CC1([C@H]2CCC(=C)[C@@H]1C2)C  Original
# 15356-60-2    165675          C[C@H]1CC[C@@H]([C@H](C1)O)C(C)C  Original
# 2217-02-9    6997371       C[C@@]12CC[C@@H](C1)C([C@@H]2O)(C)C  Original
# 5157-89-1      62335    C[C@H]1CC[C@@H]([C@H](C1)OC(=O)C)C(C)C  Original
# 27779-29-9     90350    C[C@H]1[C@@H]2C[C@@H](C2(C)C)C[C@@H]1O  Original
# 19894-97-4     88301             CC1([C@H]2CC=C([C@@H]1C2)CO)C  Original
# 2552-91-2      75699    C[C@@H]1CC[C@H]([C@H](C1)OC(=O)C)C(C)C  Original
# 14073-97-3     26447             C[C@@H]1CC[C@H](C(=O)C1)C(C)C  Original
# 25465-65-0  10524983      C[C@@H]1[C@H]2C[C@H](C2(C)C)C[C@H]1O  Original
# 42072-39-9    641003                             CC[C@H](C)CCO  Original
# 1565-80-6    2723602                              CC[C@H](C)CO  Original
# 464-45-9     1201518            C[C@]12CC[C@H](C1(C)C)C[C@H]2O  Original
# 7787-20-4      82229           C[C@@]12CC[C@@H](C1)C(C2=O)(C)C  Original
# 5989-54-8     439250                    CC1=CC[C@H](CC1)C(=C)C  Original
# 498-15-7      443156              CC1=CC[C@@H]2[C@H](C1)C2(C)C  Original
# 57717-97-2  11788398                  CC(=C)[C@@H]1CCC(=CC1)CO  Original
# 2216-51-5      16666         C[C@@H]1CC[C@H]([C@@H](C1)O)C(C)C  Original
# 18680-27-8  10219606    C[C@@]1([C@H]2C[C@H](C2(C)C)C[C@H]1O)O  Original
# 39516-03-5    641354                    C[C@H](CCC1=CC=CC=C1)O  Original
# 19902-08-0  10290825              CC1([C@@H]2CCC(=C)[C@H]1C2)C  Mirrored
# 89-78-1       165675          C[C@H]1CC[C@@H]([C@H](C1)O)C(C)C  Mirrored
# 512-13-0      439711          C[C@]12CC[C@H](C1)C([C@H]2O)(C)C  Mirrored
# 89-48-5       220674   C[C@@H]1CC[C@H]([C@@H](C1)OC(=O)C)C(C)C  Mirrored
# 1196-00-5   10524983      C[C@@H]1[C@H]2C[C@H](C2(C)C)C[C@H]1O  Mirrored
# 6712-78-3     636475             CC1([C@@H]2CC=C([C@H]1C2)CO)C  Mirrored
# 3391-87-5     443159             C[C@H]1CC[C@@H](C(=O)C1)C(C)C  Mirrored
# 24041-60-9     90350    C[C@H]1[C@@H]2C[C@@H](C2(C)C)C[C@@H]1O  Mirrored
# 70224-28-1   6999792                            CC[C@@H](C)CCO  Mirrored
# 616-16-0      637572                             CC[C@@H](C)CO  Mirrored
# 464-43-7     6552009         C[C@@]12CC[C@@H](C1(C)C)C[C@@H]2O  Mirrored
# 4695-62-9    1201521             C[C@]12CC[C@H](C1)C(C2=O)(C)C  Mirrored
# 65996-98-7    440917                   CC1=CC[C@@H](CC1)C(=C)C  Mirrored
# 20296-50-8    442461              CC1=CC[C@H]2[C@@H](C1)C2(C)C  Mirrored
# 18457-55-1    369312                   CC(=C)[C@H]1CCC(=CC1)CO  Mirrored
# 22422-34-0   6553875  C[C@]1([C@@H]2C[C@@H](C2(C)C)C[C@@H]1O)O  Mirrored
# 22148-86-3   6994425                   C[C@@H](CCC1=CC=CC=C1)O  Mirrored
#
#             Enantiomer Strength  Odor
# 18172-67-3  19902-08-0     high     1
# 15356-60-2     89-78-1              1
# 2217-02-9     512-13-0              1
# 5157-89-1      89-48-5              1
# 27779-29-9   1196-00-5              1
# 19894-97-4   6712-78-3   medium     1
# 2552-91-2    2230-87-7              1
# 14073-97-3   3391-87-5   medium     1
# 25465-65-0  24041-60-9              1
# 42072-39-9  70224-28-1              1
# 1565-80-6     616-16-0              1
# 464-45-9      464-43-7   medium     1
# 7787-20-4    4695-62-9   medium     1
# 5989-54-8   65996-98-7   medium     1
# 498-15-7    20296-50-8              1
# 57717-97-2  18457-55-1              1
# 2216-51-5      89-78-1     high     1
# 18680-27-8  22422-34-0              1
# 39516-03-5  22148-86-3              1
# 19902-08-0  18172-67-3     high     1
# 89-78-1      2216-51-5   medium     1
# 512-13-0     2217-02-9   medium     1
# 89-48-5      5157-89-1   medium     1
# 1196-00-5   27779-29-9              1
# 6712-78-3   19894-97-4              1
# 3391-87-5   14073-97-3   medium     1
# 24041-60-9  25465-65-0              1
# 70224-28-1  42072-39-9              1
# 616-16-0     1565-80-6   medium     1
# 464-43-7      464-45-9   medium     1
# 4695-62-9    7787-20-4   medium     1
# 65996-98-7   5989-54-8              1
# 20296-50-8    498-15-7              1
# 18457-55-1  57717-97-2              1
# 22422-34-0  18680-27-8              1
# 22148-86-3  39516-03-5              1
