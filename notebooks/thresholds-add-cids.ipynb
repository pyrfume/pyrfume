# %% [markdown]
# # Add CIDS to parsed_threshold_data_in_air.csv

# %%
import pandas as pd
import pyrfume
from pyrfume.odorants import get_cid, get_cids
from rickpy import ProgressBar
df = pyrfume.load_data('thresholds/parsed_threshold_data_in_air.csv')
df = df.set_index('canonical SMILES')

# %%
smiles_cids = get_cids(df.index, kind='SMILES')
# Out:
# [-----------------------100%---------------------] 1542 out of 1542 complete
# Could not find CCCCCC1(C)CNC=CN1C
# Could not find CCC[C@@H]1CCCC(=O)S1
# Could not find CCC(=O)C1CNC=CS1
# Could not find CCCCC[C@@H]1CCCC(=O)S1
# Could not find O=[O]=O
#
#
# Could not find CCCC(=O)C1CNC=CS1
# Could not find CCCCC1(C)CNC=CN1C
# Could not find CCCC\C=C/CC(O)C=C
# Could not find CCC1=CCCC(C)(C)[C@@H]1C=CC(C)=O
# Could not find CC(=O)C=C[C@@H]1C(=C)CCCC1(C)C
# Could not find C[C@@H]1CO[C@](C)(O1)c2ccc3c(c2)[Si](C)(C)C[Si]3(C)C
# Could not find C[C@@H]1CO[C@@](C)(O1)c2ccc3c(c2)[Si](C)(C)C[Si]3(C)C
# Could not find C[C@H]1CO[C@](C)(O1)c2ccc3c(c2)[Si](C)(C)C[Si]3(C)C
# Could not find C[C@H]1CO[C@@](C)(O1)c2ccc3c(c2)[Si](C)(C)C[Si]3(C)C
# Could not find C[C@@H]1CO[C@](C)(O1)c2ccc3c(c2)C(C)(C)CC3(C)C
# Could not find C[C@@H]1CO[C@@](C)(O1)c2ccc3c(c2)C(C)(C)CC3(C)C
# Could not find C[C@H]1CO[C@](C)(O1)c2ccc3c(c2)C(C)(C)CC3(C)C
# Could not find C[C@H]1CO[C@@](C)(O1)c2ccc3c(c2)C(C)(C)CC3(C)C
# Could not find C[C@@H]1CO[C@](C)(O1)c2ccc3c(c2)[Si](C)(C)O[Si]3(C)C
# Could not find C[C@@H]1CO[C@@](C)(O1)c2ccc3c(c2)[Si](C)(C)O[Si]3(C)C
# Could not find C[C@H]1CO[C@](C)(O1)c2ccc3c(c2)[Si](C)(C)O[Si]3(C)C
# Could not find C[C@H]1CO[C@@](C)(O1)c2ccc3c(c2)[Si](C)(C)O[Si]3(C)C
# Could not find CCCCCC\C=C/CC(O)C=C
# Could not find CCCCCC\C=C/CC(=O)C=C
# Could not find CCCCCCCC1(C)CNC=CN1C
# Could not find C[C@@H]1CC[C@]2(CCC3=C([C@H]2C)C(C)(C)CCC3)C1=O
# Could not find C[C@H]1CC[C@]2(CCC3=C([C@H]2C)C(C)(C)CCC3)C1=O
# Could not find C[C@H]1C2=C(CCCC2(C)C)CC[C@]13CCCC3=O
# Could not find CCCCCCC1=NC=CN(C)C1C
# Could not find CCCCCCC1(C)CNC=CN1C
# Could not find CCC/C=C(/O)C(C)=O
# Could not find CCC\C=C/CC(O)C=C
# Could not find O=[O]=O
# Could not find CCCCC[C@@H]1CCCC(=O)S1
# Could not find CCC(=O)C1CNC=CS1
# Could not find CCC[C@@H]1CCCC(=O)S1
# Could not find CCCCCC1(C)CNC=CN1C

# %%
df = df.join(pd.Series(smiles_cids, name='CID'))
df.head()
# Out:
#                                                        ez_smiles  author  \
# canonical SMILES
# CC(=O)Nc1ccccc1                                  CC(=O)Nc1ccccc1    1968
# CC(O)=O                                                  CC(=O)O    2010
# CC(=O)OC(C)=O                                      CC(=O)OC(C)=O    1974
# CC(=O)c1ccccc1                                    CC(=O)c1ccccc1    1986
# CC(=O)[Si](C)(C(C)(C)C)C(C)(C)C  CC(=O)[Si](C)(C(C)(C)C)C(C)(C)C    2010
#
#                                                 year detection/recognition  \
# canonical SMILES
# CC(=O)Nc1ccccc1                              Laffort                   NaN
# CC(O)=O                                  Cain et al.                     d
# CC(=O)OC(C)=O                        Hellman & Small                     d
# CC(=O)c1ccccc1                            Randebrock                   NaN
# CC(=O)[Si](C)(C(C)(C)C)C(C)(C)C  Sunderkötter et al.                   NaN
#
#                                  concentration  \
# canonical SMILES
# CC(=O)Nc1ccccc1                       270.0000
# CC(O)=O                                 0.1500
# CC(=O)OC(C)=O                           0.6000
# CC(=O)c1ccccc1                          0.0012
# CC(=O)[Si](C)(C(C)(C)C)C(C)(C)C         0.5000
#
#                                  log avg reported concentration  \
# canonical SMILES
# CC(=O)Nc1ccccc1                                      270.000000
# CC(O)=O                                                0.637415
# CC(=O)OC(C)=O                                          0.761166
# CC(=O)c1ccccc1                                         0.048380
# CC(=O)[Si](C)(C(C)(C)C)C(C)(C)C                        0.500000
#
#                                  error in logspace  number of measurements  \
# canonical SMILES
# CC(=O)Nc1ccccc1                           0.000000                       1
# CC(O)=O                                   2.709674                      32
# CC(=O)OC(C)=O                             0.486752                       3
# CC(=O)c1ccccc1                            2.562653                       8
# CC(=O)[Si](C)(C(C)(C)C)C(C)(C)C           0.000000                       1
#
#                                       CID
# canonical SMILES
# CC(=O)Nc1ccccc1                       904
# CC(O)=O                               176
# CC(=O)OC(C)=O                        7918
# CC(=O)c1ccccc1                       7410
# CC(=O)[Si](C)(C(C)(C)C)C(C)(C)C  46900998

# %%
from rdkit.Chem import MolFromSmiles, MolToSmiles
df['SMILES'] = df.index
p = ProgressBar(len(smiles_cids))
for i, (old, cid) in enumerate(smiles_cids.items()):
    p.animate(i, status=old)
    if cid == 0:
        mol = MolFromSmiles(old)
        if mol is None:
            new = ''
        else:
            new = MolToSmiles(mol, isomericSmiles=True)
            if old != new:
                cid = get_cid(new, kind='SMILES')
        df.loc[old, ['SMILES', 'CID']] = [new, cid]
p.animate(i+1, status='Done')
# Out:
# [-----------------------100%---------------------] 1542 out of 1542 complete (Done)

# %%
df[df['SMILES']=='']
# Out:
#                  ez_smiles  author         year detection/recognition  \
# canonical SMILES
# O=[O]=O            O=[O]=O    2007  Cain et al.                     d
#
#                   concentration  log avg reported concentration  \
# canonical SMILES
# O=[O]=O                   0.014                        0.035884
#
#                   error in logspace  number of measurements  CID SMILES
# canonical SMILES
# O=[O]=O                    1.309684                       7    0

# %%
ozone_smiles = ozone_cid = get_cid('[O-][O+]=O', kind='SMILES')
df.loc['O=[O]=O', ['SMILES', 'CID']] = [ozone_smiles, ozone_cid]

# %%
df = df.set_index('CID').drop(['ez_smiles'], axis=1)

# %%
df = df.rename(columns={'author': 'year', 'year': 'author'})

# %%
df.head()
# Out:
#           year               author detection/recognition  concentration  \
# CID
# 904       1968              Laffort                   NaN       270.0000
# 176       2010          Cain et al.                     d         0.1500
# 7918      1974      Hellman & Small                     d         0.6000
# 7410      1986           Randebrock                   NaN         0.0012
# 46900998  2010  Sunderkötter et al.                   NaN         0.5000
#
#           log avg reported concentration  error in logspace  \
# CID
# 904                           270.000000           0.000000
# 176                             0.637415           2.709674
# 7918                            0.761166           0.486752
# 7410                            0.048380           2.562653
# 46900998                        0.500000           0.000000
#
#           number of measurements                           SMILES
# CID
# 904                            1                  CC(=O)Nc1ccccc1
# 176                           32                          CC(O)=O
# 7918                           3                    CC(=O)OC(C)=O
# 7410                           8                   CC(=O)c1ccccc1
# 46900998                       1  CC(=O)[Si](C)(C(C)(C)C)C(C)(C)C

# %%
pyrfume.save_data(df, 'thresholds/parsed_threshold_data_in_air_fixed.csv')
