# %%
import pandas as pd
import pyrfume
from pyrfume import odorants

# %%
# Load the table of CIDs by sources
file_path = pyrfume.DATA_DIR / 'odorants' / 'all_cids.csv'
all_cids = pd.read_csv(file_path).set_index('CID')

# %%
# Get info from PubChem
info = odorants.from_cids(all_cids.index)

# Turn the info into a dataframe
info = pd.DataFrame.from_records(info).set_index('CID')
info.head()
# Out:
# [-----------------------99%----------------------] 9700 out of 9764 complete (Retrieving 9700 through 9763)
#      MolecularWeight         IsomericSMILES                     IUPACName  \
# CID
# 4              75.11                CC(CN)O            1-aminopropan-2-ol
# 11             98.96               C(CCl)Cl            1,2-dichloroethane
# 47            130.14      CCC(C)C(=O)C(=O)O  3-methyl-2-oxopentanoic acid
# 49            116.11       CC(C)C(=O)C(=O)O   3-methyl-2-oxobutanoic acid
# 51            146.10  C(CC(=O)O)C(=O)C(=O)O        2-oxopentanedioic acid
#
#                             name
# CID
# 4             1-aminopropan-2-ol
# 11            1,2-dichloroethane
# 47    3-methyl-2-oxovaleric acid
# 49   3-methyl-2-oxobutanoic acid
# 51           2-ketoglutaric acid

# %%
# Join the CIDs and sources with the PubCheminfo 
df = info.join(all_cids)
df = df.rename(columns={'MolecularWeight': 'MW',
                        'IsomericSMILES': 'SMILES',
                        'name': 'Name'})
df = df[['Name', 'MW', 'SMILES', 'IUPACName'] + list(df.columns[4:])]
df.head()
# Out:
#                             Name      MW                 SMILES  \
# CID
# 4             1-aminopropan-2-ol   75.11                CC(CN)O
# 11            1,2-dichloroethane   98.96               C(CCl)Cl
# 47    3-methyl-2-oxovaleric acid  130.14      CCC(C)C(=O)C(=O)O
# 49   3-methyl-2-oxobutanoic acid  116.11       CC(C)C(=O)C(=O)O
# 51           2-ketoglutaric acid  146.10  C(CC(=O)O)C(=O)C(=O)O
#
#                         IUPACName  abraham-2013  arctander-1960  \
# CID
# 4              1-aminopropan-2-ol             1               0
# 11             1,2-dichloroethane             1               0
# 47   3-methyl-2-oxopentanoic acid             0               0
# 49    3-methyl-2-oxobutanoic acid             0               0
# 51         2-oxopentanedioic acid             0               0
#
#      bozza-cabinet  bushdid-2014  chae-2019  datta-cabinet  ...  \
# CID                                                         ...
# 4                0             0          0              0  ...
# 11               0             0          0              0  ...
# 47               0             0          0              0  ...
# 49               0             0          0              0  ...
# 51               0             0          0              0  ...
#
#      mainland-receptors  prestwick  rinberg-glomeruli  scott-2014  senselab  \
# CID
# 4                     0          0                  0           0         0
# 11                    0          0                  0           0         0
# 47                    0          0                  0           0         0
# 49                    0          0                  0           0         0
# 51                    0          0                  0           0         0
#
#      sigma-2014  smith-cabinet  sobel-2013  superscent  wakayama-2019
# CID
# 4             0              0           0           0              0
# 11            0              0           0           0              0
# 47            0              0           0           0              0
# 49            0              0           0           0              0
# 51            0              0           0           0              0
#
# [5 rows x 33 columns]

# %%
file_path = pyrfume.DATA_DIR / 'odorants' / 'all_cids_properties.csv'
df.to_csv(file_path)
