# %%
import pyrfume
df = pyrfume.load_data('arctander_1960/Arctander Master.xlsx')

# %%
from rdkit.Chem.rdinchi import InchiToInchiKey
df['InChiKey'] = df['InChiKey'].apply(lambda x: InchiToInchiKey(x) if 'InChI=' in str(x) and str(x)!='nan' else x)

# %%
from tqdm.auto import tqdm
from pyrfume.odorants import get_cid, get_cids
for index, row in tqdm(df.iterrows(), total=df.shape[0]):
    #if index < 215:
    #    continue
    cid = 0
    for j, col in enumerate(['InChiKey', 'SMILES', 'CAS', 'ChemicalName']):
        if not str(row[col]) == 'nan':
            cid = get_cid(row[col], kind=(col if j<2 else 'name'))
            if cid:
                break
    df.loc[index, 'new_CID'] = cid
# Out:
# HBox(children=(IntProgress(value=0, max=3102), HTML(value='')))
# Multiple CIDs for QTBSBXVTEAMEQO-UHFFFAOYSA-N: [176, 21980959]
# Multiple CIDs for NIXOWILDQLNWCW-UHFFFAOYSA-N: [6581, 19966351]
# Multiple CIDs for WNLRTRBMVRJNCN-UHFFFAOYSA-N: [196, 22494954]
# Multiple CIDs for QWCKQJZIFLGMSD-UHFFFAOYSA-N: [6657, 517460]
# Multiple CIDs for FUOOLUPWFVMBKG-UHFFFAOYSA-N: [6119, 5245672]
# Multiple CIDs for PRKQVKDSMLBJBJ-UHFFFAOYSA-N: [10480, 517111, 123132502]
# Multiple CIDs for NLXLAEXVIDQMFP-UHFFFAOYSA-N: [25517, 518533, 12820921, 21924987]
# Multiple CIDs for XTPLQANXHDDXIH-UHFFFAOYSA-N: [22877, 11593632]
# Multiple CIDs for XTPLQANXHDDXIH-UHFFFAOYSA-N: [22877, 11593632]
# Request Error for "[NH4+]=S"
# Multiple CIDs for RXQNHIDQIJXKTK-UHFFFAOYSA-N: [162525, 90472544]
# Multiple CIDs for WPYMKLBDIGXBTP-UHFFFAOYSA-N: [243, 20144841]
# Multiple CIDs for VSGNNIFQASZAOI-UHFFFAOYSA-L: [6116, 517040]
# Multiple CIDs for 1205-42-1: [102024, 7335, 81544]
# Multiple CIDs for KRKNYBCHXYNGOX-UHFFFAOYSA-N: [311, 19782904, 88113319]
# Multiple CIDs for GHVNFZFCNZKVNT-UHFFFAOYSA-N: [2969, 135373094]
# Multiple CIDs for PVBRXXAAPNGWGE-LGVAUZIVSA-L: [21712, 101017023, 135414246]
# Multiple CIDs for AANLCWYVVNBGEE-IDIVVRGQSA-L: [20819, 5284390, 57508779, 132778133, 135414245, 139291008]
# Multiple CIDs for BDAGIHXWWSANSR-UHFFFAOYSA-N: [284, 18971002]
# Multiple CIDs for VZCYOOQTPOCHFL-OWOJBTEDSA-N: [444972, 21883788]
# Multiple CIDs for ILRKKHJEINIICQ-OOFFSTKBSA-N: [62074, 44630310, 71774887, 138394821]
# Multiple CIDs for MNWFXJYAOYHMED-UHFFFAOYSA-N: [8094, 135372455]
# Multiple CIDs for KDYFGRWQOYBRFD-UHFFFAOYSA-N: [1110, 21952380]
# Multiple CIDs for FEWJPZIEWOKRBE-UHFFFAOYSA-N: [875, 21583978]
# Multiple CIDs for TERPINYL CINNAMATE: [20838599, 6435837, 131864443]
# Multiple CIDs for CWERGRDVMFNCDR-UHFFFAOYSA-N: [1133, 129829565]
# Multiple CIDs for AYFVYJQAPQTCCC-GBXIJSLDSA-N: [6288, 6971019]
# Multiple CIDs for QORWJWZARLRLPR-UHFFFAOYSA-H: [24456, 516943]
# Multiple CIDs for KZSNJWFQEVHDMF-BYPYZUCNSA-N: [6287, 6971018, 88733505]

# %%
df[df['new_CID'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Description, ChemicalName, OtherName, ArctanderNum, NumOfNotesChastrette, ChastretteDetails, CAS, CID, SMILES, InChiKey, MW, Density, Notes, new_CID]
# Index: []

# %%
df.join(df[[]])
# Out:
#                                             Description  \
# 0     The pure material is virtually odorless. The c...
# 1            Very faint, woody and slightly piney odor.
# 2     Pungent ethereal-nauseating odor, in high dilu...
# 3              Mild, sweet, slightly green-fruity odor.
# 4            Mild, oily-green, somewhat vegetable odor.
# ...                                                 ...
# 3097  may be encountered in perfumery as an odor pro...
# 3098  Sweet, mildly floral odor with Bitter- Almond ...
# 3099  Mild, sweet-floral, soft-balsamic odor, fresh-...
# 3100  Sweet-spicy, warm, heavy-floral, mildly animal...
# 3101  Freshly prepared material has a warm, woody-sp...
#
#                                       ChemicalName  \
# 0                                     ABIETIC ACID
# 1                                           ABITOL
# 2                                     ACETALDEHYDE
# 3     ACETALDEHYDE-BENZYL-beta-METHOXYETHYL ACETAL
# 4                   ACETALDEHYDE-Dl-iso-AMYLACETAL
# ...                                            ...
# 3097                                       XYLENOL
# 3098                                XYLYL ALDEHYDE
# 3099                       beta-meta-XYLYL ETHANOL
# 3100                                     ZINGERONE
# 3101                                   ZINGIBERENE
#
#                                               OtherName  ArctanderNum  \
# 0     Sylvic acid., dimethyl-iso-propyl-decahydrophe...             1
# 1                                                   NaN             2
# 2                                                   NaN             3
# 3                                                   NaN             4
# 4                                                   NaN             5
# ...                                                 ...           ...
# 3097                                                NaN          3098
# 3098                                                NaN          3099
# 3099                                                NaN          3100
# 3100                                                NaN          3101
# 3101                                                NaN          3102
#
#       NumOfNotesChastrette                      ChastretteDetails         CAS  \
# 0                        0                                    NaN    514-10-3
# 1                        2                            woody piney  26266-77-3
# 2                        2                         ethereal winey     75-07-0
# 3                        2                           green fruity   7492-39-9
# 4                        2                             oily green  13002-09-0
# ...                    ...                                    ...         ...
# 3097                     0                                    NaN         NaN
# 3098                     2                          floral almond         NaN
# 3099                     3                   floral balsamic rose         NaN
# 3100                     5  spicy floral animal balsamic vanillin         NaN
# 3101                     2                            woody spicy         NaN
#
#            CID                                             SMILES  \
# 0        10569  [C@H]13[C@@]([C@@H]2C(=CC1)C=C(C(C)C)CC2)(CCC[...
# 1       101602               CC(C)C1CCC2C(=C1)CCC3C2(CCCC3(C)CO)C
# 2          177                                             C(C)=O
# 3     22235151                             CC(OCCOC)OCC1=CC=CC=C1
# 4        83036                               CC(C)CCOC(C)OCCC(C)C
# ...        ...                                                ...
# 3097       NaN                               C1(=C(C(=CC=C1)O)C)C
# 3098       NaN                               CC1=CC(=C(C=C1)C=O)C
# 3099       NaN                             C1(=C(C(=CC=C1)C)CCO)C
# 3100       NaN                         O=C(C)CCC1=CC(=C(O)C=C1)OC
# 3101       NaN               [C@H]1(C=CC(=CC1)C)[C@H](CCC=C(C)C)C
#
#                          InChiKey          MW  Density Notes     new_CID
# 0     RSWGJHLUYNHPMX-ONCXSQPRSA-N     302.452      NaN   NaN     10569.0
# 1     FLMIYUXOBAUKJM-UHFFFAOYSA-N      290.48      NaN   NaN    101602.0
# 2     IKHGUXGNUITLKF-UHFFFAOYSA-N     44.0526      NaN   NaN       177.0
# 3     CNGTXGHYZBQUQS-UHFFFAOYSA-N  210.26952       NaN   NaN  22235151.0
# 4     LXKCTPBHCJDSKC-UHFFFAOYSA-N     202.334      NaN   NaN     83036.0
# ...                           ...         ...      ...   ...         ...
# 3097  QWBBPBRQALCEIZ-UHFFFAOYSA-N     122.165      NaN   NaN     10687.0
# 3098                          NaN         NaN      NaN   NaN     61814.0
# 3099  UQTWNZAKBJDDAY-UHFFFAOYSA-N     150.218      NaN   NaN     33942.0
# 3100  OJYLAHXKWMRDGS-UHFFFAOYSA-N     194.227      NaN   NaN     31211.0
# 3101  KKOXKGNSUHTUBV-LSDHHAIUSA-N     204.352      NaN   NaN     92776.0
#
# [3102 rows x 14 columns]

# %%
pyrfume.save_data(df, "arctander_1960/arctander.csv")

# %%
df.dropna(subset=["ChemicalName"]).shape
# Out:
# (3099, 14)

# %%
x = dict(df.dropna(subset=["ChemicalName"]).set_index("ChemicalName")["Description"])

# %%
dict(df.set_index('CID')["Description"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-160-9c8ccbd59fc7> in <module>
# ----> 1 dict(df.set_index('CID')["Description"])
#
# ~/.local/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4400         k = com.values_from_object(key)
#    4401
# -> 4402         k = self._convert_scalar_indexer(k, kind="getitem")
#    4403         try:
#    4404             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py in _convert_scalar_indexer(self, key, kind)
#    2866             if kind in ["getitem", "ix"] and is_float(key):
#    2867                 if not self.is_floating():
# -> 2868                     return self._invalid_indexer("label", key)
#    2869
#    2870             elif kind in ["loc"] and is_float(key):
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py in _invalid_indexer(self, form, key)
#    3074         """
#    3075         raise TypeError(
# -> 3076             f"cannot do {form} indexing on {type(self)} with these "
#    3077             f"indexers [{key}] of {type(key)}"
#    3078         )
#
# TypeError: cannot do label indexing on <class 'pandas.core.indexes.base.Index'> with these indexers [nan] of <class 'float'>
